# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\amaan\Downloads\flipkart_com-ecommerce_sample.csv")
df
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
# 20000                               NaN                        NaN
# 20001                               NaN                        NaN
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
df.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20002 entries, 0 to 20001
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  object
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
df.describe()
# Out:
#         retail_price  discounted_price
# count   19981.000000      19981.000000
# mean     2980.042724       1974.137758
# std      8996.106655       7322.603415
# min        35.000000         35.000000
# 25%       675.000000        350.000000
# 50%      1049.000000        550.000000
# 75%      1999.000000       1000.000000
# max    571230.000000     571230.000000

# %%
df.isnull().sum()
# Out:
# uniq_id                       2
# crawl_timestamp               2
# product_url                   2
# product_name                  2
# product_category_tree         2
# pid                           2
# retail_price                 80
# discounted_price             80
# image                         5
# is_FK_Advantage_product       2
# description                   4
# product_rating                2
# overall_rating                2
# brand                      5866
# product_specifications       16
# dtype: int64

# %%
#there are null value in the column as it is numeric data we will replace it by mean 
df["retail_price"] = df["retail_price"].fillna(df["retail_price"].mean())

# %%
#there are null value in the column as it is numeric data we will replace it by mean
df["discounted_price"] = df["discounted_price"].fillna(df["discounted_price"].mean())

# %%
#there are null value in the column as it is categorical data we will replace it by mode
df["brand"] = df["brand"].fillna(df["brand"].mode().iloc[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20002 entries, 0 to 20001
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20002 non-null  float64
#  7   discounted_price         20002 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  object
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    20002 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# uniq_id                     2
# crawl_timestamp             2
# product_url                 2
# product_name                2
# product_category_tree       2
# pid                         2
# retail_price                0
# discounted_price            0
# image                       5
# is_FK_Advantage_product     2
# description                 4
# product_rating              2
# overall_rating              2
# brand                       0
# product_specifications     16
# dtype: int64

# %%
# still there are null value which is less that 3% so we will drop that rows using dropna
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19981 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  19981 non-null  object
#  1   crawl_timestamp          19981 non-null  object
#  2   product_url              19981 non-null  object
#  3   product_name             19981 non-null  object
#  4   product_category_tree    19981 non-null  object
#  5   pid                      19981 non-null  object
#  6   retail_price             19981 non-null  float64
#  7   discounted_price         19981 non-null  float64
#  8   image                    19981 non-null  object
#  9   is_FK_Advantage_product  19981 non-null  object
#  10  description              19981 non-null  object
#  11  product_rating           19981 non-null  object
#  12  overall_rating           19981 non-null  object
#  13  brand                    19981 non-null  object
# ...

# %%
df.to_csv("C:/Amaan/CleanedFlipchart.csv")
df.to_csv('compressed_data.csv.gz', compression='gzip', index=False)

# %%
filtered_df = df[df['retail_price'] > 500]

count_retailed_price_greater_than_500 = filtered_df['retail_price'].count()

print("The count of product which price is greater than 500 is:",count_retailed_price_greater_than_500)
# Out:
# The count of product which price is greater than 500 is: 16643

# %%
print((df['discounted_price'].value_counts()).idxmax(),': is the maximum dicounted price')
# Out:
# 499.0 : is the maximum dicounted price

# %%
toss = ((df['overall_rating']).value_counts() / 577 * 100)
labels = toss.index  # Use the index of 'toss' as labels

plt.pie(toss, labels=labels, startangle=90, shadow=True, autopct='%1.1f%%', colors=['b', 'r'])
plt.title('overall rating percentage')
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.countplot(x='discounted_price', data=df)
plt.show()

# %%
sns.scatterplot(x='retail_price',y='discounted_price',data=df)
# Out:
# <AxesSubplot: xlabel='retail_price', ylabel='discounted_price'>
